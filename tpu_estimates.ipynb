# %% [markdown]
# # Google TPU production estimates
#
# Research notebook for the TPU chip-sales model. The model itself lives in `tpu_model.py` — this notebook runs it and explores the results: production tables, price estimates, visualizations, and sensitivity checks. To refresh the published exports and validate them against the website in one step, use `python run_chip_model.py tpu` instead.
#
# Input data (quarterly TPU revenue on Broadcom's fiscal calendar, production mix across TPU versions, manufacturing costs) comes from [this spreadsheet](https://docs.google.com/spreadsheets/d/1eGk2AAdewEO81vx-YBRTtdlhZvAMstY7vZuHrf3sgNI/edit). Chip specs (TOPS, TDP) come from epoch.ai's published chip table.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re

import tpu_model
from chip_estimates_utils import summarize_quarterly_by_chip

inputs = tpu_model.load_inputs()
# Out:
# Loaded TPU specs from epoch.ai chip_types.csv
# Loaded 14 quarters of revenue data, 6 TPU versions

# %% [markdown]
# ## Running the model
#
# The model divides each quarter's TPU revenue among TPU versions (based on production mix) and then divides by chip price, where price = manufacturing cost marked up by Broadcom's margin. It runs as a Monte Carlo simulation over all of these inputs.
#
# Chip prices for each version are presampled once and reused across every quarter. This ensures that uncertainty in chip prices is applied consistently across quarters; otherwise, sampling prices separately each quarter would cancel out much of the uncertainty in the cumulative totals. Prices are also partially correlated across TPU versions (default 0.5), which further widens the confidence intervals on aggregate totals — see the sensitivity section at the end.
#
# Results are arrays of chip-count samples keyed by quarter and version, so percentiles of any sum preserve the correlations.

# %%
results = tpu_model.run_model(inputs=inputs)
# Out:
# Simulation complete.

# %% [markdown]
# ## Quarterly production volumes by version

# %%
summarize_quarterly_by_chip(results["quarterly_samples"])
# Out:
#     Quarter               v4            v4i               v5e  \
# 0   Q1_FY23   97k (72k-128k)  30k (19k-46k)     23k (14k-34k)
# 1   Q2_FY23  132k (94k-179k)              -     47k (21k-78k)
# 2   Q3_FY23     35k (9k-60k)              -  155k (109k-216k)
# 3   Q4_FY23                -              -  291k (210k-386k)
# 4   Q1_FY24                -              -  460k (336k-602k)
# 5   Q2_FY24                -              -  412k (295k-552k)
# 6   Q3_FY24                -              -  351k (220k-519k)
# 7   Q4_FY24                -              -  355k (200k-544k)
# 8   Q1_FY25                -              -  263k (171k-385k)
# 9   Q2_FY25                -              -                 -
# 10  Q3_FY25                -              -                 -
# 11  Q4_FY25                -              -                 -
# 12  Q1_FY26                -              -                 -
# 13  Q2_FY26                -              -                 -
#
# ...

# %% [markdown]
# ## Cumulative production by version

# %%
rows = []
grand_total = np.zeros(results["n_samples"])
for version in results["versions"]:
    arr = results["cumulative_samples"][version]
    if arr.sum() > 0:
        grand_total += arr
        rows.append({"version": version,
                     "p5": int(np.percentile(arr, 5)),
                     "p50": int(np.percentile(arr, 50)),
                     "p95": int(np.percentile(arr, 95))})
rows.append({"version": "TOTAL",
             "p5": int(np.percentile(grand_total, 5)),
             "p50": int(np.percentile(grand_total, 50)),
             "p95": int(np.percentile(grand_total, 95))})
pd.DataFrame(rows)
# Out:
#   version       p5      p50      p95
# 0      v4   191599   263966   348035
# 1     v4i    18552    30240    46065
# 2     v5e  1728010  2371099  3127166
# 3     v5p   483219   667118   863830
# 4     v6e  2007593  2607433  3235283
# 5      v7   517174   681682   857504
# 6   TOTAL  5322601  6635024  8004385

# %% [markdown]
# ## TPU price estimates
#
# Price per chip = manufacturing cost / (1 - Broadcom margin). The sheet sets margins per fiscal quarter; quarters sharing the same margin range form a pricing regime, and the table shows each version's price under each regime. The model prices every quarter using its own margin from the sheet (via a deflation factor relative to the first quarter).

# %%
# Group fiscal quarters into pricing regimes by their margin range
regimes = {}
for quarter, margin in inputs["margin_by_quarter"].items():
    regimes.setdefault((margin.x, margin.y), []).append(quarter)

price_rows = []
for version, cost_dist in inputs["tpu_cost"].items():
    row = {"version": version}
    for (lo, hi), regime_quarters in regimes.items():
        price_samples = (cost_dist / (1 - inputs["margin_by_quarter"][regime_quarters[0]])) @ 10_000
        label = f"margin {lo:.0%}-{hi:.0%} ({regime_quarters[0]} to {regime_quarters[-1]})"
        row[label] = (f"${np.median(price_samples):,.0f} "
                      f"(${np.percentile(price_samples, 5):,.0f} - ${np.percentile(price_samples, 95):,.0f})")
    price_rows.append(row)
pd.DataFrame(price_rows)
# Out:
#   version margin 55%-70% (Q1_FY23 to Q4_FY23)  \
# 0      v3            $3,040 ($2,319 - $4,109)
# 1     v4i            $2,330 ($1,736 - $3,207)
# 2      v4            $3,390 ($2,672 - $4,480)
# 3     v5e            $3,056 ($2,349 - $4,137)
# 4     v5p            $6,839 ($5,531 - $8,814)
# 5     v6e            $4,599 ($3,783 - $5,858)
# 6      v7         $13,276 ($10,933 - $17,013)
#
#   margin 50%-65% (Q1_FY24 to Q4_FY25) margin 60%-70% (Q1_FY26 to Q2_FY26)
# 0            $2,681 ($2,079 - $3,571)            $3,270 ($2,577 - $4,210)
# 1            $2,057 ($1,563 - $2,761)            $2,499 ($1,915 - $3,271)
# 2            $3,012 ($2,419 - $3,876)            $3,662 ($2,991 - $4,553)
# 3            $2,690 ($2,093 - $3,551)            $3,291 ($2,602 - $4,209)
# 4            $6,022 ($4,957 - $7,568)            $7,355 ($6,158 - $8,955)
# 5            $4,057 ($3,394 - $5,061)            $4,966 ($4,259 - $5,943)
# 6          $11,743 ($9,808 - $14,668)         $14,317 ($12,226 - $17,172)

# %% [markdown]
# ## Visualizations
#
# Median H100-equivalent compute and unit volumes per Broadcom fiscal quarter, stacked by TPU version.

# %%
# Aliases and helpers shared by the two charts below
quarterly_samples = results["quarterly_samples"]
QUARTERS = results["quarters"]
TPU_VERSIONS = results["versions"]
TPU_SPECS = results["specs"]
H100_TOPS = tpu_model.H100_TOPS

TPU_COLORS = {
    'v3': 'lightcoral',
    'v4i': '#ffffb3',
    'v4': '#bebada',
    'v5e': '#fb8072',
    'v5p': '#80b1d3',
    'v6e': '#fdb462',
    'v7': '#b3de69',
}

CANONICAL_VERSIONS = ['v3', 'v4i', 'v4', 'v5e', 'v5p', 'v6e', 'v7']

_qfy_re = re.compile(r"^Q([1-4])_FY(\d{2})$")

def parse_qfy(qfy: str):
    m = _qfy_re.match(qfy)
    if not m:
        raise ValueError(f"Invalid quarter format: {qfy}")
    return int(m.group(1)), 2000 + int(m.group(2))

def qfy_sort_key(qfy: str):
    q, fy = parse_qfy(qfy)
    return (fy, q)

month_abbr = {1:"Jan",2:"Feb",3:"Mar",4:"Apr",5:"May",6:"Jun",
              7:"Jul",8:"Aug",9:"Sep",10:"Oct",11:"Nov",12:"Dec"}
fq_to_start_month = {1:11, 2:2, 3:5, 4:8}
fq_to_end_month = {1:1, 2:4, 3:7, 4:10}

def fiscal_qfy_to_month_range_label(qfy: str) -> str:
    q, fy = parse_qfy(qfy)
    sm = fq_to_start_month[q]
    em = fq_to_end_month[q]
    start_year = fy - 1 if q == 1 else fy
    end_year = fy
    if q == 1:
        return f"{month_abbr[sm]} '{str(start_year)[-2:]} - {month_abbr[em]} '{str(end_year)[-2:]}"
    else:
        return f"{month_abbr[sm]} - {month_abbr[em]} '{str(end_year)[-2:]}"

# Median units and H100e per (fiscal quarter, version), for the stacked bars
export_rows = []
for quarter in QUARTERS:
    for version in TPU_VERSIONS:
        arr = quarterly_samples[quarter][version]
        h100e_arr = arr * (TPU_SPECS[version]['tops'] / H100_TOPS)
        export_rows.append({
            'quarter': quarter,
            'version': version,
            'chips_p50': int(np.percentile(arr, 50)),
            'h100e_p50': int(np.percentile(h100e_arr, 50)),
        })

export_df = pd.DataFrame(export_rows)

# %%
# H100e capacity by version (stacked bar)
df_plot = export_df.copy()
df_plot['h100e_p50'] = pd.to_numeric(df_plot['h100e_p50'], errors="coerce").fillna(0.0)

pivot = (
    df_plot.pivot_table(index='quarter', columns='version', values='h100e_p50', aggfunc="sum")
    .fillna(0.0)
)
pivot = pivot.reindex(index=sorted(pivot.index, key=qfy_sort_key))
present = [v for v in CANONICAL_VERSIONS if v in pivot.columns]
pivot = pivot.reindex(columns=present, fill_value=0.0)

quarters = pivot.index.tolist()
quarter_labels = [fiscal_qfy_to_month_range_label(q) for q in quarters]

data = pivot / 1000.0
totals = data.sum(axis=1).values

def fiscal_year_total(fy: int) -> float:
    mask = pivot.index.astype(str).str.contains(f"FY{str(fy)[-2:]}")
    return pivot.loc[mask].sum().sum() / 1000.0

def separator_after(qfy_target: str):
    if qfy_target in quarters:
        return quarters.index(qfy_target) + 0.5
    return None

sep1 = separator_after("Q4_FY23")
sep2 = separator_after("Q4_FY24")

fig, ax = plt.subplots(figsize=(14, 7))
x = np.arange(len(quarters))
width = 0.7

bottom = np.zeros(len(quarters))
for v in data.columns:
    vals = data[v].values
    ax.bar(x, vals, width, bottom=bottom, label=f"TPU {v}", color=TPU_COLORS.get(v), edgecolor="white", linewidth=0.5)
    for i, val in enumerate(vals):
        if val >= 40:
            ax.text(x[i], bottom[i] + val / 2, v, ha="center", va="center", fontsize=9, fontweight="bold")
    bottom += vals

pad = max(2, 0.02 * max(totals)) if len(totals) else 2
for i, total in enumerate(totals):
    ax.text(x[i], total + pad, f"{total:,.0f}k", ha="center", va="bottom", fontsize=9, fontweight="bold", color="#333333")

ax.set_ylabel("Compute Capacity (H100 equivalents)", fontsize=12)
ax.set_title("Google TPU Compute Capacity by Version (H100e)", fontsize=14, fontweight="bold")
ax.set_xticks(x)
ax.set_xticklabels(quarter_labels, rotation=45, ha="right", fontsize=9)
ax.set_ylim(0, max(totals) * 1.12 if len(totals) else 1)
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: f"{y:,.0f}k"))

if sep1 is not None: ax.axvline(x=sep1, color="gray", linestyle="--", alpha=0.5, linewidth=1)
if sep2 is not None: ax.axvline(x=sep2, color="gray", linestyle="--", alpha=0.5, linewidth=1)

y_top = ax.get_ylim()[1] * 0.98
for fy in (2023, 2024, 2025):
    idxs = [i for i, q in enumerate(quarters) if q.endswith(f"FY{str(fy)[-2:]}")]
    if idxs:
        ax.text(np.mean(idxs), y_top, f"Broadcom FY{fy}: {fiscal_year_total(fy)/1000:.2f}M H100e", ha="center", fontsize=10, color="gray")

ax.legend(loc="upper left", bbox_to_anchor=(1.01, 1), frameon=False)
plt.tight_layout()
plt.show()

# %%
# TPU unit volumes by version (stacked bar)
df = export_df[['quarter', 'version', 'chips_p50']].copy()
df['chips_p50'] = pd.to_numeric(df['chips_p50'], errors="coerce")

pivot = (
    df.pivot_table(index='quarter', columns='version', values='chips_p50', aggfunc="sum")
    .fillna(0.0)
)
pivot = pivot.reindex(index=sorted(pivot.index, key=qfy_sort_key))
present = [v for v in CANONICAL_VERSIONS if v in pivot.columns]
pivot = pivot.reindex(columns=present, fill_value=0.0)

quarters = pivot.index.tolist()
quarter_labels = [fiscal_qfy_to_month_range_label(q) for q in quarters]

data_k = pivot / 1000.0
totals_k = data_k.sum(axis=1).values

def fiscal_year_total_k(fy_full: int) -> float:
    fy_suffix = str(fy_full)[-2:]
    mask = pivot.index.str.endswith(f"FY{fy_suffix}")
    return pivot.loc[mask].to_numpy().sum() / 1000.0

sep1 = separator_after("Q4_FY23")
sep2 = separator_after("Q4_FY24")

fig, ax = plt.subplots(figsize=(14, 7))
x = np.arange(len(quarters))
width = 0.7

bottom = np.zeros(len(quarters))
for v in data_k.columns:
    vals = data_k[v].values
    ax.bar(x, vals, width, bottom=bottom, label=f"TPU {v}", color=TPU_COLORS.get(v), edgecolor="white", linewidth=0.5)
    for i, val in enumerate(vals):
        if val >= 40:
            ax.text(x[i], bottom[i] + val / 2, v, ha="center", va="center", fontsize=9, fontweight="bold", color="black")
    bottom += vals

pad = max(15, 0.02 * max(totals_k))
for i, total in enumerate(totals_k):
    ax.text(x[i], total + pad, f"{total:,.0f}k", ha="center", va="bottom", fontsize=9, fontweight="bold", color="#333333")

ax.set_ylabel("TPU Chips Produced", fontsize=12)
ax.set_title("TPU Production Volume (Units)", fontsize=14, fontweight="bold")
ax.set_xticks(x)
ax.set_xticklabels(quarter_labels, rotation=45, ha="right", fontsize=9)
ax.set_ylim(0, max(totals_k) * 1.12)
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: f"{y:,.0f}k"))

if sep1 is not None: ax.axvline(sep1, color="gray", linestyle="--", alpha=0.5)
if sep2 is not None: ax.axvline(sep2, color="gray", linestyle="--", alpha=0.5)

y_top = ax.get_ylim()[1] * 0.98
for fy_full in (2023, 2024, 2025):
    idxs = [i for i, q in enumerate(quarters) if q.endswith(f"FY{str(fy_full)[-2:]}")]
    if idxs:
        ax.text(np.mean(idxs), y_top, f"Broadcom FY{fy_full}: {fiscal_year_total_k(fy_full)/1000:.2f}M", ha="center", fontsize=10, color="gray")

ax.legend(loc="upper left", bbox_to_anchor=(1.01, 1), frameon=False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Sensitivity: price correlation across TPU versions
#
# How much does the assumed correlation between chip prices matter? Rerun the whole model at several correlation values and compare the cumulative H100e confidence interval. Each rerun uses the same random seed, so runs differ only by the correlation parameter (the original notebook did not reseed between runs, so numbers here differ slightly from old versions of this table).

# %%
CORRELATION_VALUES = [0.0, 0.3, 0.5, 0.7, 0.9, 0.99]
latest_cq = list(results["calendar_running_totals_samples"].keys())[-1]

def cumulative_h100e_total(run):
    h100e = np.zeros(run["n_samples"])
    for version in run["versions"]:
        if version in run["specs"]:
            arr = run["calendar_running_totals_samples"][latest_cq][version]
            h100e += arr * (run["specs"][version]['tops'] / tpu_model.H100_TOPS)
    return h100e

sensitivity_rows = []
for rho in CORRELATION_VALUES:
    # Reuse the main run for the default correlation; rerun the model otherwise
    if rho == results["price_correlation"]:
        run = results
    else:
        run = tpu_model.run_model(price_correlation=rho, inputs=inputs)
    p5, p50, p95 = (np.percentile(cumulative_h100e_total(run), p) / 1e6 for p in (5, 50, 95))
    sensitivity_rows.append({
        "price correlation": f"{rho}" + (" (default)" if rho == results["price_correlation"] else ""),
        "p5 (M H100e)": round(p5, 2),
        "p50 (M H100e)": round(p50, 2),
        "p95 (M H100e)": round(p95, 2),
        "90% CI width": round(p95 - p5, 2),
        "p5 vs p50": f"{(p5 - p50) / p50 * 100:+.1f}%",
        "p95 vs p50": f"{(p95 - p50) / p50 * 100:+.1f}%",
    })

sensitivity_df = pd.DataFrame(sensitivity_rows)
print(f"Cumulative H100e through {latest_cq}")
sensitivity_df
# Out:
# Simulation complete.
# Simulation complete.
# Simulation complete.
# Simulation complete.
# Simulation complete.
# Cumulative H100e through Q2 2026
#   price correlation  p5 (M H100e)  p50 (M H100e)  p95 (M H100e)  90% CI width  \
# 0               0.0          4.15           4.84           5.50          1.35
# 1               0.3          4.01           4.84           5.65          1.65
# 2     0.5 (default)          3.92           4.84           5.74          1.82
# 3               0.7          3.84           4.84           5.82          1.98
# 4               0.9          3.76           4.84           5.90          2.14
# 5              0.99          3.74           4.84           5.95          2.21
#
#   p5 vs p50 p95 vs p50
# 0    -14.2%     +13.7%
# 1    -17.2%     +16.8%
# 2    -19.1%     +18.7%
# 3    -20.6%     +20.4%
# 4    -22.3%     +21.9%
# 5    -22.9%     +22.8%

# %% [markdown]
# ## Export
#
# Write the csv_export/ and owners_csv_export/ files. The canonical refresh path is `python run_chip_model.py tpu`, which also validates the exports against the published website data.

# %%
exported = tpu_model.export_csvs(results)
# Out:
# Exported 29 rows to csv_export/tpu_fiscal_quarter_chip_timelines.csv
# Exported 35 rows to csv_export/tpu_calendar_quarter_chip_timelines.csv
# Exported 65 rows to csv_export/tpu_cumulative_by_chip.csv
# Exported 65 rows to owners_csv_export/tpu_owners_cumulative_by_chip.csv
# Exported 35 rows to owners_csv_export/tpu_owners_quarters_by_chip.csv
# Exported 14 rows to owners_csv_export/tpu_owners_cumulative_totals.csv
# Exported 15 rows to csv_export/tpu_cumulative_totals.csv
